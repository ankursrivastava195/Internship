# %%
# !pip install selenium

# %%
import selenium

# %%
from selenium import webdriver

# %%
import pandas as pd

# %%
from selenium.webdriver.common.by import By

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'CompanyName':company_name,'ExperienceRequired':experience_required})
df
# Out:
#                                   Title  \
# 0                          Data Analyst
# 1                          Data Analyst
# 2                          Data Analyst
# 3                      IBP Data Analyst
# 4                      IBP Data Analyst
# 5  Data Analyst - Control Services Team
# 6                          Data Analyst
# 7                          Data Analyst
# 8                          Data Analyst
# 9                          Data Analyst
#
#                                             Location  \
# 0                                Bangalore/Bengaluru
# 1  Hybrid - Bangalore/ Bengaluru, Karnataka, Gurg...
# 2                    Bangalore/ Bengaluru, Karnataka
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# 6                                             Remote
# 7  Hybrid - Bangalore/Bengaluru, Kolkata, Hyderab...
# ...

# %%
#Ans-2
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
#       2 search.click()
#
# NameError: name 'driver' is not defined

# %%
job_title=[]
job_location=[]
company_name=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'CompanyName':company_name})
df
# Out:
# Empty DataFrame
# Columns: [Title, Location, CompanyName]
# Index: []

# %%
#Ans-3
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
salary=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]")
salary.click()

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[3]/label/p/span[1]")
location.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'CompanyName':company_name,'ExperienceRequired':experience_required})
df

# %%
#Ans-4
driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('sunglasses')

# %%
submit=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
submit.click()

# %%
name=[]
brand=[]
price=[]
size=[]

# %%
while(len(name) < 100):
    nametags=driver.find_elements(By.CLASS_NAME,"_2B099V")
    for i in nametags:
        if(len(name) == 100):
            break
        details=(i.text).split('\n')
        
        name.append(details[0])
        brand.append(details[1])
        price.append(details[2])
        
    if(len(name) < 100):
        nextclick=driver.find_element(By.CLASS_NAME,"ge-49M")
        nextclick.click()

price

# %%
import pandas as pd
df=pd.DataFrame({'Product_Name':name,'Brand':brand, 'Price':price})
df

# %%
#Ans-5
driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('apple-iphone-11-black-64-gb')

# %%
submit=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
submit.click()

# %%
rating=[]
review=[]
fullReview=[]

# %%
reviewelement=driver.find_element(By.CLASS_NAME,"_2_R_DZ")
reviewelement.click()

# %%
allreviews=driver.find_element(By.XPATH,"//span[text()='Reviews']")
allreviews.click()

# %%
driver.maximize_window()

# %%
while(len(review) < 100):
    reviews=driver.find_elements(By.CLASS_NAME,"col _2wzgFH")
    for i in reviews:
        if(len(reviews) == 100):
            break
        details=(i.text).split('\n')
        
       # rating.append(details[0])
        review.append(details)
        #fullReview.append(details[2])
        
    if(len(review) < 100):
        #nextclick=driver.find_element_by_link_text('2')
        #nextclick.click()
        driver.find_element(By.XPATH, "//a[text()='2']")

reviews

# %%
#Ans-6
driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('sneakers')

# %%
submit=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
submit.click()

# %%
name=[]
brand=[]
price=[]
size=[]

# %%
while(len(name) < 100):
    nametags=driver.find_elements(By.CLASS_NAME,"_2B099V")
    for i in nametags:
        if(len(name) == 100):
            break
        details=(i.text).split('\n')
        
        name.append(details[0])
        brand.append(details[1])
        price.append(details[2])
        
    if(len(name) < 100):
        nextclick=driver.find_element(By.CLASS_NAME,"ge-49M")
        nextclick.click()

# %%
import pandas as pd
df=pd.DataFrame({'Brand':name,'Product Description':brand, 'Price':price})
df

# %%
#ans 7


driver.get("https://www.amazon.in/")

# %%
search=driver.find_element(By.CLASS_NAME,"nav-input")
search.send_keys('laptop')

# %%
submit=driver.find_element(By.CLASS_NAME,"nav-search-submit-text")
submit.click()

# %%
cpuselected=driver.find_element(By.XPATH,"//span[text()='Intel Core i7']")
cpuselected.click()

# %%
title=[]
ratings=[]
price=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-small a-spacing-top-small"]')
for i in title_tags[1:11]:
    titlevalue=i.text
    title.append((titlevalue.split("\n")[0]))
    ratings.append((titlevalue.split("\n")[1]))
    price.append((titlevalue.split("\n₹")[1]).split(" M.R.P:")[0])

# %%
import pandas as pd
df=pd.DataFrame({'Name':title,'Ratings':ratings, 'Price':price})
df
# Out:
#                                                 Name             Ratings  \
# 0  ASUS Vivobook 15, Intel Core i7-12650H 12th Ge...                 240
# 1  Dell Inspiron 5430 13th Gen Laptop, Intel i7-1...                   5
# 2  MSI GF63 Thin, Intel Core i7-11800H, 40CM FHD ...                   3
# 3  Acer Nitro 5 AN515-58 Gaming Laptop 12th Gen I...                  53
# 4  ASUS TUF Gaming F15 (2023) 90WHr Battery, Inte...                  30
# 5  Lenovo IdeaPad Slim 3 Intel Core i7 11th Gen 1...                  10
# 6  MSI GF63 Thin, Intel Core i7-11800H, 40CM FHD ...                  77
# 7  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...                  75
# 8  HP Pavilion Plus 14, 12th Gen Intel Core i7-12...                 185
# 9  ASUS Creator Series Vivobook 16X (2023), Intel...  Great Freedom Sale
#
#       Price
# 0    59,990
# 1    85,990
# 2    68,990
# 3    99,990
# 4  1,15,990
# 5    56,990
# 6    60,990
# 7    79,990
# 8    93,990
# 9    81,990

# %%
#Ans-8
driver.get("https://www.azquotes.com/")

# %%
topQuotes=driver.find_element(By.XPATH,"//a[text()='Top Quotes']")
topQuotes.click()

# %%
quotes=[]
author=[]
tags=[]
quoteWrap=[]

# %%
while(len(quotes) < 1000):
    quoteWrap=driver.find_elements(By.XPATH,'//div[@class="wrap-block"]')
    for i in quoteWrap:
        quote=(i.text).split('\n')
        quotes.append(quote[0])
        author.append(quote[1])
        tags.append(quote[2])
        
    if(len(quotes) < 901):
            nextclick=driver.find_element(By.XPATH,"//a[text()='Next →']")
            nextclick.click()
tags
# Out:
# ['Essence, Deep Thought, Transcendentalism',
#  'Inspiration, Past, Trying',
#  'Country, Peace, War',
#  'Inspirational, Motivational, Death',
#  '4th Of July, Food, Patriotic',
#  'Inspirational, Success, Basketball',
#  'Strong, Revenge, Intelligent',
#  'Inspirational, Teacher, Religious',
#  'Truth, Honesty, Lying',
#  'Funny, Reading, Learning',
#  'Strong, Thoughtful, Compassion',
#  'Love, Funny, Life',
#  'Freedom, Men, Democracies Have',
#  'God, Religious, Atheist',
#  'Respect, Kindness, Character',
#  'Inspirational, Motivational, Change',
#  'Inspirational, Life, Inspiring',
#  'Love, Inspirational, Life',
#  'Inspiring, Country, 4th Of July',
#  'Inspirational, Dream, Hate',
#  'Love, Inspirational, Life',
#  'Forgiveness, God, Christian',
#  'Country, Men, Squares',
#  'Inspirational, Relationship, Positive',
#  'Inspirational, Motivational, Positive',
#  'Love, Friendship, Relationship',
#  'Faith, God, Christian',
#  'Art, Freedom, Political Will',
# ...

# %%
import pandas as pd
df=pd.DataFrame({'Quote':quotes,'Author':author, 'Type Of Quotes':tags})
df
# Out:
#                                                  Quote              Author  \
# 0    The essence of strategy is choosing what not t...      Michael Porter
# 1    One cannot and must not try to erase the past ...          Golda Meir
# 2    Patriotism means to stand by the country. It d...  Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...      Nelson Mandela
# 4    You have to love a nation that celebrates its ...        Erma Bombeck
# ..                                                 ...                 ...
# 995  Regret for the things we did can be tempered b...    Sydney J. Harris
# 996  America... just a nation of two hundred millio...  Hunter S. Thompson
# 997  For every disciplined effort there is a multip...            Jim Rohn
# 998  The spiritual journey is individual, highly pe...            Ram Dass
# 999  The mind is not a vessel to be filled but a fi...            Plutarch
#
#                                Type Of Quotes
# ...
